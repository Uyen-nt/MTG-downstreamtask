# %%
# !git clone https://github.com/Uyen-nt/MTG-downstreamtask.git

# %%
# %cd MTG-downstreamtask

# %%
# !git pull origin main

# %%
# !pip install pytorch-pretrained-bert

# %%
# !python behrt/preprocess_mimic.py

# %%
# !python behrt/train_mimic.py
